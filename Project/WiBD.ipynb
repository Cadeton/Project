# %%
import datasist as ds

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
# warnings.filter warnings (ignore)
import warnings

# %%
Test = pd.read_csv('Test.csv')
Train = pd.read_csv('Train.csv')
Sample = pd.read_csv('SampleSubmission.csv')
Var = pd.read_csv('variable_descriptions.csv')
Test_id = Test['ward']

# %%
Var.head()
# Out:
#   Column                                        Description Unnamed: 2  \
# 0  dw_00  Percentage of dwellings of type: House or bric...        NaN
# 1  dw_01  Percentage of dwellings of type: Traditional d...        NaN
# 2  dw_02  Percentage of dwellings of type: Flat or apart...        NaN
# 3  dw_03  Percentage of dwellings of type: Cluster house...        NaN
# 4  dw_04  Percentage of dwellings of type: Townhouse (se...        NaN
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
pd.set_option("display.max_columns", 100)

# %%
pcode= Test['ADM4_PCODE']

# %%
# Train.drop(columns = 'dw_12', 'dw_13', 'lan_13', 'pw_07', 'pw_08', 'ADM4_PCODE' axis = 1, inplace = True)
# Test.drop(columns = 'dw_12', 'dw_13', 'lan_13', 'pw_07', 'pw_08',  'ADM4_PCODE', axis =1, inplace = True)

# %%
Train.head()
# Out:
#                ward  total_households  total_individuals     target     dw_00  \
# 0  41601001: Ward 1        1674.45058         5888.20750  16.773757  0.933841
# 1  41601002: Ward 2        1736.99230         6735.33812  21.496661  0.696940
# 2  41601003: Ward 3        2403.57591         7273.04995  10.931425  0.810545
# 3  41601004: Ward 4        1740.78737         5734.49046  23.119257  0.659914
# 4  41601005: Ward 5        1730.51451         6657.23835  13.652252  0.950575
#
#       dw_01     dw_02     dw_03     dw_04     dw_05     dw_06     dw_07  \
# 0  0.000846  0.005490  0.000676  0.000000  0.001372  0.005750  0.031466
# 1  0.001253  0.004402  0.000000  0.002301  0.001323  0.007575  0.123547
# 2  0.004517  0.008891  0.003986  0.007735  0.000956  0.006686  0.022632
# 3  0.000000  0.006129  0.000000  0.000813  0.037245  0.005255  0.068909
# 4  0.000655  0.001473  0.000598  0.006999  0.000818  0.004985  0.009150
#
# ...

# %%
Train["lan_13"].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: lan_13, dtype: int64

# %%
Train.dtypes
# Out:
# ward                  object
# total_households     float64
# total_individuals    float64
# target               float64
# dw_00                float64
# dw_01                float64
# dw_02                float64
# dw_03                float64
# dw_04                float64
# dw_05                float64
# dw_06                float64
# dw_07                float64
# dw_08                float64
# dw_09                float64
# dw_10                float64
# dw_11                float64
# dw_12                  int64
# dw_13                  int64
# psa_00               float64
# psa_01               float64
# psa_02               float64
# psa_03               float64
# psa_04               float64
# stv_00               float64
# stv_01               float64
# car_00               float64
# car_01               float64
# lln_00               float64
# lln_01               float64
# lan_00               float64
#                       ...
# lan_04               float64
# ...

# %%
Train.shape
# Out:
# (2822, 63)

# %%
Test.shape
# Out:
# (1013, 62)

# %%
Test.dtypes
# Out:
# ward                  object
# total_households     float64
# total_individuals    float64
# dw_00                float64
# dw_01                float64
# dw_02                float64
# dw_03                float64
# dw_04                float64
# dw_05                float64
# dw_06                float64
# dw_07                float64
# dw_08                float64
# dw_09                float64
# dw_10                float64
# dw_11                float64
# dw_12                float64
# dw_13                float64
# psa_00               float64
# psa_01               float64
# psa_02               float64
# psa_03               float64
# psa_04               float64
# stv_00               float64
# stv_01               float64
# car_00               float64
# car_01               float64
# lln_00               float64
# lln_01               float64
# lan_00               float64
# lan_01               float64
#                       ...
# lan_04               float64
# ...

# %%
Sample.head()
# Out:
#                ward  target
# 0  21001001: Ward 1   21.87
# 1  21001002: Ward 2   65.94
# 2  21001003: Ward 3   83.65
# 3  21001004: Ward 4     NaN
# 4  21001005: Ward 5     NaN

# %%
Train.isnull().sum()
# Out:
# ward                 0
# total_households     0
# total_individuals    0
# target               0
# dw_00                0
# dw_01                0
# dw_02                0
# dw_03                0
# dw_04                0
# dw_05                0
# dw_06                0
# dw_07                0
# dw_08                0
# dw_09                0
# dw_10                0
# dw_11                0
# dw_12                0
# dw_13                0
# psa_00               0
# psa_01               0
# psa_02               0
# psa_03               0
# psa_04               0
# stv_00               0
# stv_01               0
# car_00               0
# car_01               0
# lln_00               0
# lln_01               0
# lan_00               0
#                     ..
# lan_04               0
# lan_05               0
# lan_06               0
# lan_07               0
# lan_08               0
# lan_09               0
# lan_10               0
# lan_11               0
# lan_12               0
# ...

# %%
Train.drop(columns = 'ward', inplace = True)
Test.drop(columns = 'ward', inplace = True)

# %%
Train.drop(['dw_12', 'dw_13', 'lan_13', 'pw_07', 'pw_08', 'ADM4_PCODE'], axis = 1, inplace= True)
Test.drop(['dw_12', 'dw_13', 'lan_13', 'pw_07', 'pw_08', 'ADM4_PCODE'], axis = 1, inplace= True)

# %%
Test.head()
# Out:
#    total_households  total_individuals     dw_00     dw_01     dw_02  \
# 0        2504.95194         8745.15151  0.947257  0.000873  0.002021
# 1        2080.27718         7258.11764  0.844993  0.000481  0.043629
# 2        1106.62639         5919.13170  0.651380  0.007937  0.007113
# 3        2175.56096        10280.57452  0.410837  0.002468  0.011511
# 4        1270.83883         6018.34202  0.942851  0.002638  0.000821
#
#       dw_03     dw_04     dw_05     dw_06     dw_07     dw_08     dw_09  \
# 0  0.000000  0.000000  0.030116  0.000452  0.013018  0.003516  0.000000
# 1  0.004714  0.012323  0.012300  0.022132  0.022412  0.016969  0.006702
# 2  0.000000  0.001977  0.259711  0.006505  0.044153  0.013530  0.000000
# 3  0.000485  0.000000  0.449604  0.009256  0.101963  0.001516  0.009203
# 4  0.000000  0.000891  0.000787  0.000830  0.027930  0.001617  0.017343
#
#       dw_10     dw_11    psa_00    psa_01    psa_02    psa_03    psa_04  \
# ...

# %%
Test.isnull().sum()
# Out:
# total_households     0
# total_individuals    0
# dw_00                0
# dw_01                0
# dw_02                0
# dw_03                0
# dw_04                0
# dw_05                0
# dw_06                0
# dw_07                0
# dw_08                0
# dw_09                0
# dw_10                0
# dw_11                0
# psa_00               0
# psa_01               0
# psa_02               0
# psa_03               0
# psa_04               0
# stv_00               0
# stv_01               0
# car_00               0
# car_01               0
# lln_00               0
# lln_01               0
# lan_00               0
# lan_01               0
# lan_02               0
# lan_03               0
# lan_04               0
# lan_05               0
# lan_06               0
# lan_07               0
# lan_08               0
# lan_09               0
# lan_10               0
# lan_11               0
# lan_12               0
# lan_14               0
# pg_00                0
# ...

# %%
cat_col = (Train.select_dtypes(include = 'object').columns)

# %%
cat_col
# Out:
# Index([], dtype='object')

# %%
cat_col = [n for n in Train.columns if Train[n].dtypes == 'object']

cat_encode = []
for cat in cat_col:
    temp = len(Train[cat].unique())
    if temp > 1 :
        cat_encode.append(cat)

# %%
Joint_data = pd.concat([Train, Test], sort = False)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

for col in cat_col:
    lb.fit(Joint_data[col])
    Joint_data[col] = lb.transform(Joint_data[col])

# %%
Train = Joint_data[0:Train.shape[0]]
Train.shape
# Out:
# (2822, 56)

# %%
Test = Joint_data[Train.shape[0]:]
Test.shape
# Out:
# (1013, 56)

# %%
y_target = Train['target']

# %%
Train.drop(columns = 'target', inplace = True)
Test.drop(columns = 'target', inplace = True)
# Out:
# /home/cadeton/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
sc.fit(Train)

Train = sc.transform(Train)
Test = sc.transform(Test)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(Train,y_target, test_size = 0.1, random_state = 0)

# %%
from sklearn.metrics import mean_squared_error

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor

# %%
light = LGBMRegressor(n_estimators=800,boosting_type='gbdt',num_leaves=25, max_depth=-2,learning_rate=0.1)
light.fit(X_train, y_train)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=-2,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=800, n_jobs=-1, num_leaves=25, objective=None,
#               random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
pred = light.predict(X_test)

# %%
mean_squared_error(pred, y_test)
# Out:
# 9.616144445088791

# %%
#grad = GradientBoostingRegressor(learning_rate=0.1,
    #n_estimators=100,
    #subsample=1.0)
#grad.fit(X_train,y_train)

# %%
#pred = grad.predict(X_test)

# %%
#mean_squared_error(pred, y_test)

# %%
cat = CatBoostRegressor(iterations=1000, best_model_min_trees=1,learning_rate=0.1, random_seed=1,
    depth=1)
cat.fit(X_train, y_train)
# Out:
# 0:	learn: 9.8068904	total: 89.3ms	remaining: 1m 29s
# 1:	learn: 9.3814357	total: 93.1ms	remaining: 46.5s
# 2:	learn: 9.0148790	total: 97.1ms	remaining: 32.3s
# 3:	learn: 8.6316965	total: 100ms	remaining: 24.9s
# 4:	learn: 8.3005700	total: 105ms	remaining: 20.9s
# 5:	learn: 8.0162921	total: 108ms	remaining: 17.9s
# 6:	learn: 7.7311931	total: 113ms	remaining: 16s
# 7:	learn: 7.4713900	total: 115ms	remaining: 14.3s
# 8:	learn: 7.2364823	total: 117ms	remaining: 12.8s
# 9:	learn: 7.0080834	total: 118ms	remaining: 11.7s
# 10:	learn: 6.8415995	total: 120ms	remaining: 10.8s
# 11:	learn: 6.6661729	total: 122ms	remaining: 10s
# 12:	learn: 6.4998660	total: 124ms	remaining: 9.4s
# 13:	learn: 6.3445938	total: 126ms	remaining: 8.9s
# 14:	learn: 6.2144409	total: 128ms	remaining: 8.41s
# 15:	learn: 6.0754158	total: 130ms	remaining: 7.97s
# 16:	learn: 5.9567817	total: 131ms	remaining: 7.58s
# 17:	learn: 5.8330289	total: 133ms	remaining: 7.24s
# 18:	learn: 5.7228480	total: 134ms	remaining: 6.93s
# ...

# %%
pred = cat.predict(X_test)

# %%
mean_squared_error(pred, y_test)
# Out:
# 12.151731220123366

# %%
#dr_model = DecisionTreeRegressor(random_state= 1, presort=False,max_depth=3, min_samples_split=3)
#dr_model.fit(X_train, y_train)

# %%
#pred = dr_model.predict(X_test)

# %%
mean_squared_error(pred, y_test)
# Out:
# 9.616144445088791

# %%
#rd_model = RandomForestRegressor(n_estimators=200, n_jobs=5, max_depth=3, random_state=10)
#rd_model.fit(X_train, y_train)

# %%
#pred = rd_model.predict(X_test)

# %%
#mean_squared_error(pred, y_test)

# %%
final_pred = cat.predict(Test)

# %%
final_pred
# Out:
# array([19.18517124, 13.69699187, 20.47675743, ..., 17.50009456,
#        14.53756327, 16.27868596])

# %%
Sample['ward'] = Test_id
Sample['target'] = final_pred

# %%
Sample.head()
# Out:
#                ward     target
# 0  21001001: Ward 1  19.185171
# 1  21001002: Ward 2  13.696992
# 2  21001003: Ward 3  20.476757
# 3  21001004: Ward 4  16.511954
# 4  21001005: Ward 5  20.899448

# %%
len(final_pred)
# Out:
# 1013

# %%
Sample.to_csv("light2_sub.csv", index=False)

# %%
#ligh1 gave me the best sub so far 3.68
cats sub 3.66
